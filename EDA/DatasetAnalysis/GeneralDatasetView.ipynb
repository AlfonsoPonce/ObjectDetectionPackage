# %%
from pathlib import Path
from easyimages import EasyImageList

image_folder = Path(f"../input/drone_dataset/train/images")

Li = EasyImageList.from_folder(image_folder)

Li.visualize_grid_html(Li.images)
# Out:
# <div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=[] src='../input/drone_dataset/train/images/2143.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=[] src='../input/drone_dataset/train/images/3468.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=[] src='../input/drone_dataset/train/images/820.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=[] src='../input/drone_dataset/train/images/510.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=[] src='../input/drone_dataset/train/images/60.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=[
# ...
